# %%
import pandas as pd

df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
# C:\Users\Thanakrit\AppData\Local\Temp\ipykernel_11956\2853589298.py:3: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('survey_results_public.csv')
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
# ...

# %%
filt = df['Employment'] == 'Employed'
df_employ = df.loc[filt]
df_employ
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 3               4                     I am a developer by profession
# 7               8                     I am a developer by profession
# 8               9                     I am a developer by profession
# ...           ...                                                ...
# 49184       49185  I am not primarily a developer, but I write co...
# 49185       49186                     I am a developer by profession
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# ...

# %%
#create CSV file and use \ instead comma
df_employ.to_csv('data.tsv', sep='\t')

# %%
#create xlsx
df_employ.to_excel('data.xlsx')

# %%
#JSON file

df_employ.to_json('data.json', orient='records', lines=True)

# %%
test = pd.read_json('data.json', orient='records', lines=True)
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               4                     I am a developer by profession
# 3               8                     I am a developer by profession
# 4               9                     I am a developer by profession
# ...           ...                                                ...
# 33745       49185  I am not primarily a developer, but I write co...
# 33746       49186                     I am a developer by profession
# 33747       49187                        I code primarily as a hobby
# 33748       49188                     I am a developer by profession
# 33749       49189                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# ...

# %%
#SQL database
#Download pip install SQLAlchemy psycopg2-binary
# from sqlalchemy import create_engine
# import psycopg2
#
# engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')
# india_df.to_sql('sample_table', engine, if_exists='replace')
# sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')
#
# sql_df.head()
#
# sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df
# Out:
#                                               title  \
# 0                                   My Updated Post
# 1                                     A Second Post
# 2                      Top 5 Programming Lanaguages
# 3                      Sublime Text Tips and Tricks
# 4                                  Best Python IDEs
# 5                Flask vs Django - Which Is Better?
# 6         You Won't Believe These Clickbait Titles!
# 7         These Beers Will Improve Your Programming
# 8                          List of PyCon 2018 Talks
# 9     How Dogs in the Workplace Boosts Productivity
# 10                    The Best Programming Podcasts
# 11                         Tips for Public Speaking
# 12              Best Programmers Throughout History
# 13                  How To Create A YouTube Channel
# 14                           How I Record My Videos
# 15                               Python and Physics
# 16            Just A Few More Healines Should Do It
# ...
