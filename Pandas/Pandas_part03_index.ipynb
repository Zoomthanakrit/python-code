# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
df.loc['CoreyMSchafer@gmail.com', 'last']
# Out:
# 'Schafer'

# %%
df.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
schema_df = pd.read_csv("survey_results_schema.csv", index_col='qid')

# %%
schema_df
# Out:
#                   qname                                           question  \
# qid
# QID18     TechEndorse_1  What attracts you to a technology or causes yo...
# QID18     TechEndorse_2  What attracts you to a technology or causes yo...
# QID18     TechEndorse_3  What attracts you to a technology or causes yo...
# QID18     TechEndorse_4  What attracts you to a technology or causes yo...
# QID18     TechEndorse_5  What attracts you to a technology or causes yo...
# ...                 ...                                                ...
# QID103  AIAgentObsWrite  Was the tool or tools for AI agent observabili...
# QID92   AIAgentExternal  You indicated you use or develop AI agents as ...
# QID104  AIAgentExtWrite  Was the out-of-the-box agents, copilots or ass...
# QID100          AIHuman  In the future, if AI can do most coding tasks,...
# QID93            AIOpen  Looking ahead 3–5 years, what skills do you be...
#
#        type                                      sub  sq_id
# qid
# QID18    RO  AI integration or AI Agent capabilities    1.0
# QID18    RO                          Easy-to-use API    2.0
# QID18    RO                  Robust and complete API    3.0
# QID18    RO     Customizable and manageable codebase    4.0
# QID18    RO                   Reputation for quality    5.0
# ...     ...                                      ...    ...
# QID103   TE                                      NaN    NaN
# QID92    MC                                      NaN    NaN
# QID104   TE                                      NaN    NaN
# QID100   MC                                      NaN    NaN
# QID93    TE                                      NaN    NaN
#
# [139 rows x 5 columns]

# %%
schema_df.sort_index(ascending=True)
# Out:
#                        qname  \
# qid
# QID10        LearnCodeChoose
# QID100               AIHuman
# QID102      AIAgentOrchWrite
# QID103       AIAgentObsWrite
# QID104       AIAgentExtWrite
# ...                      ...
# QID91   AIAgentObserveSecure
# QID92        AIAgentExternal
# QID93                 AIOpen
# QID97             SOFriction
# QID99          AIFrustration
#
#                                                  question type  sub  sq_id
# qid
# QID10   Did you begin learning to code or learn a new ...   MC  NaN    NaN
# QID100  In the future, if AI can do most coding tasks,...   MC  NaN    NaN
# QID102  Was the tool or tools for AI agent orchestrati...   TE  NaN    NaN
# QID103  Was the tool or tools for AI agent observabili...   TE  NaN    NaN
# QID104  Was the out-of-the-box agents, copilots or ass...   TE  NaN    NaN
# ...                                                   ...  ...  ...    ...
# QID91   You indicated you use or develop AI agents as ...   MC  NaN    NaN
# QID92   You indicated you use or develop AI agents as ...   MC  NaN    NaN
# QID93   Looking ahead 3–5 years, what skills do you be...   TE  NaN    NaN
# QID97   When you visit Stack Overflow, how often is it...   MC  NaN    NaN
# QID99   When using AI tools, which of the following pr...   MC  NaN    NaN
#
# [139 rows x 5 columns]
