# %%
people = {
    "first": ["Corey", 'Jane', 'John', 'Adam'],
    "last": ["Schafer", 'Doe', 'Doe', 'Doe'],
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com', 'A@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
#Sort one column
df.sort_values(by = 'last', ascending = False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
#Sort multiple column
df.sort_values(by = ['last', 'first'], ascending = True)
# Out:
#    first     last                    email
# 3   Adam      Doe              A@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
df.sort_values(by = ['last', 'first'], ascending = [False, True], inplace = True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 3   Adam      Doe              A@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df['last'].sort_index()
# Out:
# 0    Schafer
# 1        Doe
# 2        Doe
# 3        Doe
# Name: last, dtype: object

# %%
df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df
# Out:
# C:\Users\Thanakrit\AppData\Local\Temp\ipykernel_14836\3804311939.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('survey_results_public.csv')
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# ...

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed                                                33750
# Independent contractor, freelancer, or self-employed     6708
# Student                                                  4428
# Not employed                                             2227
# Retired                                                   708
# I prefer not to say                                       518
# Name: count, dtype: int64

# %%
df.sort_values(by = ['Employment', 'ConvertedCompYearly'], ascending=[True, False], inplace = True)
df[['Employment', 'ConvertedCompYearly']].head(10)
# Out:
#       Employment  ConvertedCompYearly
# 28700   Employed           33552715.0
# 43143   Employed           18387548.0
# 35353   Employed           15430267.0
# 45971   Employed           13921760.0
# 24900   Employed            9531653.0
# 10025   Employed            9000000.0
# 30728   Employed            6371285.0
# 40418   Employed            6000000.0
# 25268   Employed            2500000.0
# 5410    Employed            2346000.0

# %%
#Check top 10 method 1
df['ConvertedCompYearly'].nlargest(10)
# Out:
# 34267    50000000.0
# 28700    33552715.0
# 43143    18387548.0
# 35353    15430267.0
# 45971    13921760.0
# 48428    10000000.0
# 24900     9531653.0
# 10025     9000000.0
# 37352     6890299.0
# 30728     6371285.0
# Name: ConvertedCompYearly, dtype: float64

# %%
#Check top 10 method 1#Check top 10 method 2
df.nsmallest(10, 'ConvertedCompYearly')
# Out:
#        ResponseId                                         MainBranch  \
# 34567       34568                     I am a developer by profession
# 20026       20027                     I am a developer by profession
# 26961       26962                     I am a developer by profession
# 48524       48525                     I am a developer by profession
# 48600       48601  I used to be a developer by profession, but no...
# 47176       47177                     I am a developer by profession
# 34865       34866                     I am a developer by profession
# 9012         9013                              I am learning to code
# 12407       12408                     I am a developer by profession
# 13304       13305                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# 34567  25-34 years old                          Primary/elementary school
# ...
