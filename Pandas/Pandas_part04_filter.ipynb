# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# & and
# | or
filt = (df['last'] == 'Doe') | (df['first'] == 'John')

# %%
df[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
#~ opposite
df.loc[~filt, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# Name: email, dtype: object

# %%
df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
# C:\Users\Thanakrit\AppData\Local\Temp\ipykernel_13756\2288075619.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('survey_results_public.csv')
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
# ...

# %%
high_salary = df['ConvertedCompYearly']>70000
df_salary = df.loc[high_salary, ['Age', 'AIAgentExternal', 'ConvertedCompYearly']]
df_salary
# Out:
#                    Age                AIAgentExternal  ConvertedCompYearly
# 1      25-34 years old                            NaN             104413.0
# 5      45-54 years old                 GitHub Copilot             120000.0
# 7      35-44 years old                            NaN              72000.0
# 22     25-34 years old                            NaN              87500.0
# 25     55-64 years old  ChatGPT;GitHub Copilot;Replit             108913.0
# ...                ...                            ...                  ...
# 49066  35-44 years old                            NaN             138470.0
# 49075  25-34 years old                            NaN              82366.0
# 49083  35-44 years old                            NaN             188000.0
# 49084  55-64 years old                            NaN             119000.0
# 49088  35-44 years old                            NaN             280000.0
#
# [12702 rows x 3 columns]

# %%
age = ['25-34 years old', '35-44 years old']
filt_2 = df_salary['Age'].isin(age)

df_salary.loc[filt_2,:]
# Out:
#                    Age                       AIAgentExternal  \
# 1      25-34 years old                                   NaN
# 7      35-44 years old                                   NaN
# 22     25-34 years old                                   NaN
# 28     35-44 years old  ChatGPT;GitHub Copilot;Google Gemini
# 29     35-44 years old                                   NaN
# ...                ...                                   ...
# 49028  25-34 years old                                   NaN
# 49066  35-44 years old                                   NaN
# 49075  25-34 years old                                   NaN
# 49083  35-44 years old                                   NaN
# 49088  35-44 years old                                   NaN
#
#        ConvertedCompYearly
# 1                 104413.0
# 7                  72000.0
# 22                 87500.0
# 28                 78000.0
# 29                205000.0
# ...                    ...
# 49028              77000.0
# ...

# %%
filt_3 = df_salary['AIAgentExternal'].str.contains('Claude', na=False)

df_salary.loc[filt_3, 'AIAgentExternal']
# Out:
# 42       ChatGPT;Claude Code;GitHub Copilot;Microsoft C...
# 49        ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 61        ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 69                                     ChatGPT;Claude Code
# 85       ChatGPT;Claude Code;GitHub Copilot;Google Gemi...
#                                ...
# 48856    Claude Code;GitHub Copilot;Microsoft Copilot;v...
# 48928                            Claude Code;Google Gemini
# 48930     ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 48937     ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 48967         Claude Code;GitHub Copilot;Microsoft Copilot
# Name: AIAgentExternal, Length: 1438, dtype: object
